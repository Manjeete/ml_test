# %%
import pandas as pd

# %%
ecom = pd.read_csv("summer2020.csv")

# %%
len(ecom)
# Out:
# 1573

# %%
ecom.head()
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# ...

# %%
ecom.describe()
# Out:
#              price  retail_price     units_sold  uses_ad_boosts       rating  \
# count  1573.000000   1573.000000    1573.000000     1573.000000  1573.000000
# mean      8.325372     23.288620    4339.005086        0.432931     3.820896
# std       3.932030     30.357863    9356.539302        0.495639     0.515374
# min       1.000000      1.000000       1.000000        0.000000     1.000000
# 25%       5.810000      7.000000     100.000000        0.000000     3.550000
# 50%       8.000000     10.000000    1000.000000        0.000000     3.850000
# 75%      11.000000     26.000000    5000.000000        1.000000     4.110000
# max      49.000000    252.000000  100000.000000        1.000000     5.000000
#
#        rating_count  rating_five_count  rating_four_count  rating_three_count  \
# count   1573.000000        1528.000000        1528.000000         1528.000000
# mean     889.659250         442.263743         179.599476          134.549738
# ...

# %%
len(ecom.dtypes)
# Out:
# 43

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
ecom('price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b633accf9e1e> in <module>
# ----> 1 ecom('price')
#
# TypeError: 'DataFrame' object is not callable

# %%
ecom['price']
# Out:
# 0       16.00
# 1        8.00
# 2        8.00
# 3        8.00
# 4        2.72
#         ...
# 1568     6.00
# 1569     2.00
# 1570     5.00
# 1571    13.00
# 1572     7.00
# Name: price, Length: 1573, dtype: float64

# %%
ecom['price'].mean()
# Out:
# 8.325371900826447

# %%
ecom['price'].sum()
# Out:
# 13095.810000000001

# %%
ecom['price'].plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-c8ded903f6e9> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 ecom['price'].plot()
#
# E:\Project\mlproject\venv\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-109> in matplotlib(self, line)
#
# E:\Project\mlproject\venv\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
ecom.index
# Out:
# RangeIndex(start=0, stop=1573, step=1)

# %%
ecom.describe()
# Out:
#              price  retail_price     units_sold  uses_ad_boosts       rating  \
# count  1573.000000   1573.000000    1573.000000     1573.000000  1573.000000
# mean      8.325372     23.288620    4339.005086        0.432931     3.820896
# std       3.932030     30.357863    9356.539302        0.495639     0.515374
# min       1.000000      1.000000       1.000000        0.000000     1.000000
# 25%       5.810000      7.000000     100.000000        0.000000     3.550000
# 50%       8.000000     10.000000    1000.000000        0.000000     3.850000
# 75%      11.000000     26.000000    5000.000000        1.000000     4.110000
# max      49.000000    252.000000  100000.000000        1.000000     5.000000
#
#        rating_count  rating_five_count  rating_four_count  rating_three_count  \
# count   1573.000000        1528.000000        1528.000000         1528.000000
# mean     889.659250         442.263743         179.599476          134.549738
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
ecom['price'].dtype
# Out:
# dtype('float64')

# %%
len(ecom['price'])
# Out:
# 1573

# %%
ecom.loc[100:200]
# Out:
#                                                  title  \
# 100  6 Couleurs Automne Été Dames Casual Lâche Soli...
# 101  2018 6 Couleurs d'été de la mode d'été des fem...
# 102  2020 Hommes Summer Fashion Brand Summer Suits ...
# 103  Women Summer Off Shoulder V-neck Bow Top Top C...
# 104  Pnma Hommes Été À Séchage Rapide Shorts Hommes...
# ..                                                 ...
# 196  Mode féminine Vintage évider robe en dentelle ...
# 197  Chemise en mousseline de soie pour femmes sans...
# 198  Femmes Halter Long Sling Dress Swing Print Boh...
# 199  Robe à bretelles lâche col en v pour femmes d'...
# 200  Summer Women Casual Sleeveless Loose Tops Libr...
#
#                                             title_orig  price  retail_price  \
# 100  6 Colors Autumn Summer Ladies Casual Loose Sol...   9.00             8
# 101  2018 6 Color Summer Women’s New Fashion Sexy C...   6.00             8
# ...

# %%
ecom.iloc[:10]
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
# 5  Plus la taille d'été femmes décontracté sans m...
# 6  Women Fashion Loose Lace Blouse Blouse V Neck ...
# 7  Robe tunique ample femme Robe d'été Robe en je...
# 8  Robe d'été décontractée à manches courtes pour...
# 9  Femmes d'été, plus la taille décontractée lâch...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# ...

# %%
ecom['title']
# Out:
# 0       2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1       SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2       2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3       Hot Summer Cool T-shirt pour les femmes Mode T...
# 4       Femmes Shorts d'été à lacets taille élastique ...
#                               ...
# 1568    Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569    10 couleurs femmes shorts d'été lacent ceintur...
# 1570    Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571    Mode femmes d'été sans manches robes col en V ...
# 1572    Pantalon de yoga pour femmes à la mode Slim Fi...
# Name: title, Length: 1573, dtype: object

# %%
ecom[ecom['price'] <=10]
# Out:
#                                                   title  \
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# 5     Plus la taille d'été femmes décontracté sans m...
# ...                                                 ...
# 1567  Combinaison sans manches pour femmes couleur u...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2     2020 New Arrival Women Spring and Summer Beach...   8.00            43
# ...

# %%
len(ecom[ecom['price']< 8])
# Out:
# 677

# %%
len(pd.crosstab(ecom['price'],ecom['retail_price']))
# Out:
# 127

# %%
ecom.groupby(['price']).mean()
# Out:
#        retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# price
# 1.00            8.0       270.0             0.4   3.568          23.8
# 1.65            2.0      1000.0             1.0   3.670         191.0
# 1.66            2.0       550.0             1.0   3.980          26.5
# 1.67            2.0       100.0             1.0   3.590          32.0
# 1.68            2.0       460.0             1.0   3.744          65.0
# ...             ...         ...             ...     ...           ...
# 24.00          59.0      1000.0             1.0   4.210         762.0
# 25.00          38.0        50.0             1.0   3.170           6.0
# 26.00         168.0       100.0             1.0   4.150          20.0
# 27.00          23.0        50.0             1.0   4.250          12.0
# 49.00          42.0       100.0             0.0   4.670           6.0
#
#        rating_five_count  rating_four_count  rating_three_count  \
# price
# ...

# %%
ecom['price'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-96c38afc25b9> in <module>
# ----> 1 ecom['price'].plot()
#
# E:\Project\mlproject\venv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     867
#     868     def __call__(self, *args, **kwargs):
# --> 869         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     870
#     871         x, y, kind, kwargs = self._get_call_args(
#
# E:\Project\mlproject\venv\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1778             import pandas.plotting._matplotlib as module
#    1779         except ImportError:
# -> 1780             raise ImportError(
#    1781                 "matplotlib is required for plotting when the "
#    1782                 'default backend "matplotlib" is selected.'
#
# ...

# %%
ecom["price"].hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-4de2181dccab> in <module>
# ----> 1 ecom["price"].hist()
#
# E:\Project\mlproject\venv\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      82     matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      83     """
# ---> 84     plot_backend = _get_plot_backend(backend)
#      85     return plot_backend.hist_series(
#      86         self,
#
# E:\Project\mlproject\venv\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1778             import pandas.plotting._matplotlib as module
#    1779         except ImportError:
# -> 1780             raise ImportError(
#    1781                 "matplotlib is required for plotting when the "
# ...

# %%
len(ecom.dropna())
# Out:
# 62

# %%
len(ecom)
# Out:
# 1573

# %%
ecom = ecom.dropna()

# %%
len(ecom)
# Out:
# 62

# %%
ecom
# Out:
#                                                   title  \
# 39    5 Couleur Femmes De Mode D'été Mince Sans Manc...
# 57    Sexy Solid Solid Ruffled Chiffon Sling Top Pur...
# 76    Femmes Mode Combinaison Courte Spaghetti Strap...
# 140   2018 New Fashion Women Casual Playsuit Dames J...
# 157   Summer Fashion Women - Robe décontractée sans ...
# ...                                                 ...
# 1413  Grande taille mode femmes été débardeurs décon...
# 1418  ZANZEA - Damen Sommer Mode Lose Rundhals Baumw...
# 1465  Pantalon de yoga sport couleur unie pour femme...
# 1534  Femmes Chemisier d'été Chemise Sexy Floral Che...
# 1558  Mode d'été pour dames Jumpsuit sans manches im...
#
#                                              title_orig  price  retail_price  \
# 39    5 Color Women's Fashion Summer Slim Sleeveless...   13.0            13
# 57    Sexy Solid Ruffled Chiffon Sling Top Pure Colo...    9.0             8
# ...

# %%
ecom = pd.read_csv('summer2020.csv')

# %%
ecom
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
len(ecom)
# Out:
# 1573

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
len(ecom['has_urgency_banner'])
# Out:
# 1573

# %%
ecom['has_urgency_banner'] = ecom['has_urgency_banner'].fillna(ecom['has_urgency_banner'].mean())

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
ecom['urgency_text'].dtype
# Out:
# dtype('O')

# %%
ecom['merchant_profile_picture'].dtype
# Out:
# dtype('O')

# %%
ecom.drop('price', axis=1)
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress            22
# 2     2020 New Arrival Women Spring and Summer Beach...            43
# ...

# %%
ecom
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
ecom = ecom.drop('merchant_profile_picture',axis=1)

# %%
ecom
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
ecom = ecom.drop('urgency_text',axis=1)

# %%
ecom
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
ecom.sample(frac=1)
# Out:
#                                                   title  \
# 439   4 Couleur Nouveau Été Femmes Mode Abeille Moti...
# 383   2019 nouvelles femmes mode S-5XL chemisier déc...
# 198   Femmes Halter Long Sling Dress Swing Print Boh...
# 486   Femmes été longue robe spaghetti sangle col en...
# 589   S-5XL Shorts de causalité d'été pour femmes Pa...
# ...                                                 ...
# 368   Femmes sexy soutien-gorge rembourré hauts col ...
# 986   Femmes Shorts d'été à lacets taille élastique ...
# 456    Pantalon à bretelles 3 couleurs Nouvelle mode...
# 1403  Summer New Women Casual Sleeveless  Jumpsuits ...
# 725   2019 femmes dames mode dentelle crochetée robe...
#
#                                              title_orig  price  retail_price  \
# 439   4 Color New Summer Women Fashion Bee Pattern P...   11.0            10
# 383   2019 New Women Fashion S-5XL Casual Blouse Wom...    9.0             8
# ...

# %%
ecom.sample(frac=0.5)
# Out:
#                                                   title  \
# 1110  S~XXXXXXXL Mode d'été Femme Sexy Col en V Ferm...
# 46    Costume de sport cool pour hommes d'été Vêteme...
# 1171  Women's Sleeveless Sleeveless Deep V-neckage P...
# 390   Robe d'été de mode Sexy femmes Casual sans man...
# 346   2020 New  Women Summer Fashion O-neck Sleevele...
# ...                                                 ...
# 296   Femmes Mode Sexy Tie Dye Imprimé Deux Pièces E...
# 881   Femmes d'été Sling Dress V-cou Floral Strap pl...
# 495   T-shirt à manches courtes T-shirt jersey sans ...
# 686   Femmes été décontracté lâche couleur unie salo...
# 732   2020 New  Women Summer Fashion O-neck Sleevele...
#
#                                              title_orig  price  retail_price  \
# 1110  S~XXXXXL Summer  Fashion Woman Sexy V-neck Zip...   6.00            38
# 46    Summer mens cool sport suit Sports Wear Casual...  16.00            14
# ...
